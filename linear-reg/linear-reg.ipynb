# %% [markdown]
# # 4 May

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

data = {
    'Hours': [1, 2, 3, 4, 5],
    "Marks": [35, 40, 45, 50, 55]
}

df = pd.DataFrame(data)

X = df[['Hours']]
y = df['Marks']

model = LinearRegression()
model.fit(X, y)

# Prediction
print("Prediction for 6 hours:", model.predict([[6]]))

# Slope & Intercept
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Prediction for 6 hours: [60.]
# Slope: 4.999999999999999
# Intercept: 30.000000000000004
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Visualization (Graph)

import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

data = {
    'Hours': [1, 2, 3, 4, 5],
    "Marks": [35, 40, 45, 50, 55]
}

df = pd.DataFrame(data)

X = df[['Hours']]
y = df['Marks']

plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.xlabel('Hours Studied')
plt.ylabel('Marks')
plt.legend()
plt.show()

# %%
# Error Metrics
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

data = {
    'Hours': [1, 2, 3, 4, 5],
    "Marks": [35, 40, 45, 50, 55]
}

df = pd.DataFrame(data)

X = df[['Hours']]
y = df['Marks']

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Absolute Error: 0.0
# Mean Squared Error: 0.0
# Root Mean Squared Error: 0.0

# %%
# Prediction & Spilitting Data
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

data = {
    'Hours': [1, 2, 3, 4, 5],
    "Marks": [35, 40, 45, 50, 55]
}

df = pd.DataFrame(data)

X = df[['Hours']]
y = df['Marks']

model = LinearRegression()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("Actual:", y_test.values)
print("Predicted:", y_pred)
# Out:
# Actual: [40]
# Predicted: [40.]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv('data.csv')

X = df[['Numbers']]
y = df['Squares']

model = LinearRegression()
model.fit(X, y)
print(model.predict([[6]]))
# Out:
# [39.]
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

data = {
    'Hours': [1, 2, 3, 4, 5],
    'Marks': [35, 40, 45, 50, 55]
}

df_outlier = pd.DataFrame(data)

# Adding an outlier
df_outlier.loc[len(df_outlier)] = [10, 10]

X = df_outlier[['Hours']]
y = df_outlier['Marks']

model = LinearRegression()
model.fit(X, y)

plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.show()

# %%
# Multi Linear Regression
import pandas as pd
from sklearn.linear_model import LinearRegression

data = {
    'Hours': [1, 2, 3, 4, 5],
    'Sleep': [7, 6, 5, 4, 3],
    'Marks': [35, 40, 45, 50, 55]
}

df = pd.DataFrame(data)

X = df[['Hours', 'Sleep']]
y = df['Marks']

model = LinearRegression()
model.fit(X, y)

print(f"Prediction: {model.predict([[6, 2]])}")
# Out:
# Prediction: [60.]
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
