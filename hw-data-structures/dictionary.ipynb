# %% [markdown]
# # Dictionary

# %%
# Create a dictionary with student names as keys and marks as values
students = {
    "Anakin" : 85,
    "Luke" : 90,
    "Leia" : 95,
    "R2-D2" : 80,
    "Han" : 65
}

print(students)

# Display students scoring above 75
print("Students scoring above 75:")
for student, marks in students.items():
    if marks > 75:
        print(f"{student}")

# Average marks
average_marks = sum(students.values()) / len(students)
print("Average Marks:", average_marks)
# Out:
# {'Anakin': 85, 'Luke': 90, 'Leia': 95, 'R2-D2': 80, 'Han': 65}
# Students scoring above 75:
# Anakin
# Luke
# Leia
# R2-D2
# Average Marks: 83.0
